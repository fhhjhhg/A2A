# %% [markdown]
# <a href="https://colab.research.google.com/github/fhhjhhg/A2A/blob/main/copy_of_untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
from google.colab import files

# --- 1. The Financial Roadmap (CSV) ---
roadmap_data = [
    ["Date", "Phase", "Action Item", "Income (In)", "Expense (Out)", "Balance (Saved)", "Credit Score Goal", "Notes"],
    ["2/1/2026", "Ignition", "LLC Filing (IL)", "0", "150", "850", "564", "Legitimizes Business for Write-offs"],
    ["2/2/2026", "Credit", "GLCU Credit Builder Loan (0% APR)", "0", "0", "850", "570", "Locks $1k (No cost), Reports 'Paid as Agreed'"],
    ["2/2/2026", "Credit", "GLCU Secured Visa Deposit", "0", "2000", "-1150", "570", "Uses 'Stealth Capital' for 5% Utilization trick"],
    ["2/4/2026", "Credit", "Pay-for-Delete 'ALDOUS'", "0", "114", "-1264", "590", "Removes derogatory mark"],
    ["2/5/2026", "Hardware", "NVIDIA Jetson Orin Nano", "0", "220", "-1484", "590", "Micro Center Deal (Use Coupon)"],
    ["2/15/2026", "Ops", "Gig Work (Feb 1-15)", "1000", "0", "-484", "595", "Target: Loop Lunch Rush"],
    ["2/28/2026", "Ops", "Gig Work (Feb 16-28)", "1000", "0", "516", "600", "Target: Logan Square Dinner"],
    ["3/1/2026", "Hardware", "XREAL Air 2 Ultra + Beam", "0", "900", "-384", "610", "The 'Centaur' Interface"],
    ["3/15/2026", "Ops", "Gig Work (Mar 1-15)", "1000", "0", "616", "615", "Deploy 'Vision Agent'"],
    ["3/31/2026", "Ops", "Gig Work (Mar 16-31)", "1000", "0", "1616", "620", "VA Loan Eligible Zone"],
    ["4/1/2026", "Hardware", "Meshtastic LoRA Nodes (x3)", "0", "150", "1466", "630", "Stealth Comms Network"],
    ["4/30/2026", "Savings", "Gig Income (Apr)", "2000", "0", "3466", "640", "House Fund Growing"],
    ["5/30/2026", "Savings", "Gig Income (May)", "2000", "0", "5466", "650", "Start Looking for 3-Flat"],
    ["6/30/2026", "Savings", "Gig Income (Jun)", "2000", "0", "7466", "660", ""],
    ["7/30/2026", "Savings", "Gig Income (Jul)", "2000", "0", "9466", "670", ""],
    ["8/30/2026", "Savings", "Gig Income (Aug)", "2000", "0", "11466", "680", ""],
    ["9/30/2026", "Savings", "Gig Income (Sep)", "2000", "0", "13466", "690", ""],
    ["10/31/2026", "Acquisition", "Buy 3-Unit (FHA/Conv 5%)", "0", "12000", "1466", "700", "Down Payment + Closing Costs"]
]

with open('centaur_roadmap.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(roadmap_data)

# --- 2. The SOPs (Markdown) ---
sops_content = """# PROJECT: CENTAUR PROTOCOL
**Owner:** Stealth Architect
**Mission:** Achieve Algorithmic Independence via Real Estate & AI.

## I. The Credit Engineering Script (GLCU)
* **Target:** Great Lakes Credit Union (Branch Visit Required).
* **Ask 1:** "I want to open a **Credit Builder Loan** for $1,000. I understand the funds are frozen in savings. I want the 12-month term at 0% interest."
* **Ask 2:** "I also want to open a **Share Secured Visa** using $2,000 of my own funds as collateral. Please set the Auto-Pay to 'Statement Balance'."
* **Collection Script (Call ALDOUS):** "I am disputing this debt. However, to resolve it immediately, I will pay the full $114 via debit card today if you agree to send a letter confirming this account will be **deleted** from my report, or at minimum marked 'Paid in Full' with $0 balance."

## II. The "Permit Velocity" Python Spec
**System:** You are a Real Estate Data Scientist.
**Task:** Create a Python script using `pandas`, `folium`, and `sodapy`.
**Objective:**
1. Connect to Chicago Data Portal API (`building-permits`).
2. Filter for "Renovation" and "New Construction" permits (last 12 mo).
3. Group by Zip Code. Calculate "Velocity" (Current vs Last Year).
4. Visualize on Folium map: Red = High Velocity, Blue = Low Velocity.
5. **Stealth Layer:** Cross-reference with ShotSpotter data to find "Safe Blocks" in "Red Zones."

## III. The Hardware Lab Spec
* **Compute:** NVIDIA Jetson Orin Nano (Edge AI Server).
* **Network:** Nebula Overlay (Secure P2P) + Meshtastic (LoRA Off-grid).
* **Visual:** XREAL Air 2 Ultra (3-Screen AR Desktop).
* **Bio-Fab:** Bambu Lab A1 + Algae Filament (Future "Living Wall" product).
"""

with open('centaur_sops.md', 'w') as f:
    f.write(sops_content)

# --- 3. The Action List (Text) ---
tasks_content = """[ ] Admin: File Illinois LLC Articles of Organization ($150)
[ ] Credit: Call ALDOUS collection agency for "Pay-for-Delete" ($114)
[ ] Banking: Go to GLCU branch (Uptown/Douglas) -> Open Credit Builder Loan
[ ] Banking: Open GLCU Secured Visa ($2k deposit)
[ ] Tech: Buy NVIDIA Jetson Orin Nano at Micro Center (Use New Customer Coupon)
[ ] Tech: Install "Nebula" on Mac and Jetson for secure link
[ ] Code: Run "Chicago Permit Scraper" script (Python)
[ ] Gig: Register for DoorDash/UberEats under the LLC EIN or Personal
[ ] Ops: Buy 1TB NVMe SSD for the Jetson
[ ] Ops: Locate nearest "American Science & Surplus" for lab glass
"""

with open('zero_to_hero_tasks.txt', 'w') as f:
    f.write(tasks_content)

# --- 4. The Calendar (ICS) ---
ics_content = """BEGIN:VCALENDAR
VERSION:2.0
PRODID:-//Centaur Systems//Stealth Protocol//EN
BEGIN:VEVENT
# Out:
#   File "/tmp/ipython-input-2597329136.py", line 79
#     ics_content = """BEGIN:VCALENDAR
#                   ^
# SyntaxError: incomplete input
